# %% [markdown]
# #### **1️⃣ What is a Server?**
#
#
# **🔹 Simple definition**
#
# A **server** is a **powerful computer** whose job is to **provide services or data to other computers (clients).**
#
# Unlike your laptop:
#
# - Runs **24/7**
#
# - Has **high CPU, RAM, storage**
#
# - Optimized for **reliability and performance**
#
# - Usually placed in **data centers**

# %% [markdown]
# ![image.png](attachment:image.png)
